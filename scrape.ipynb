# %% [markdown]
# #Scraping Code

# %% [markdown]
# I first scraped the data and using Github REST API and ChatGPPT assistance and stored the raw/uncleaned data in users0.csv and repositories0.csv files.

# %% [markdown]
# **The code adheres to API rate limits of Github REST API**

# %%
import requests
import csv
import time

# GitHub API token
GITHUB_TOKEN = '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'
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"}

# Helper function to clean up company names
def clean_company_name(company):
    if company:
        company = company.strip().lstrip('@').upper()
    return company

# Function to fetch users from the GitHub API
def fetch_users(city="Berlin", min_followers=200):
    users = []
    page = 1

    while True:
        url = f"https://api.github.com/search/users?q=location:{city}+followers:>{min_followers}&page={page}&per_page=100"
        response = requests.get(url, headers=HEADERS)
        data = response.json()

        # Break if no more results
        if 'items' not in data or not data['items']:
            break

        for user in data['items']:
            # Get full user info
            user_url = user['url']
            user_response = requests.get(user_url, headers=HEADERS)
            user_data = user_response.json()

            # Extract required fields
            users.append({
                'login': user_data['login'],
                'name': user_data['name'],
                'company': clean_company_name(user_data['company']),
                'location': user_data['location'],
                'email': user_data['email'],
                'hireable': user_data['hireable'],
                'bio': user_data['bio'],
                'public_repos': user_data['public_repos'],
                'followers': user_data['followers'],
                'following': user_data['following'],
                'created_at': user_data['created_at'],
            })
        page += 1
        time.sleep(1)  # Avoid hitting API rate limits

    return users

# Function to fetch repositories for a user
def fetch_repositories(user_login):
    repositories = []
    page = 1

    while True:
        url = f"https://api.github.com/users/{user_login}/repos?per_page=100&page={page}"
        response = requests.get(url, headers=HEADERS)
        repo_data = response.json()

        # Break if no more repositories
        if not repo_data:
            break

        for repo in repo_data:
            repositories.append({
                'login': user_login,
                'full_name': repo['full_name'],
                'created_at': repo['created_at'],
                'stargazers_count': repo['stargazers_count'],
                'watchers_count': repo['watchers_count'],
                'language': repo['language'],
                'has_projects': repo['has_projects'],
                'has_wiki': repo['has_wiki'],
                'license_name': repo['license']['key'] if repo['license'] else None,
            })

        # If fewer than 100 repositories are returned, it means we're on the last page
        if len(repo_data) < 100:
            break

        page += 1  # Move to the next page
        time.sleep(1)  # Avoid hitting API rate limits

    return repositories

# Save users to CSV
def save_users_to_csv(users, filename="users0.csv"):
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=users[0].keys())
        writer.writeheader()
        writer.writerows(users)

# Save repositories to CSV
def save_repositories_to_csv(repositories, filename="repositories_0.csv"):
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=repositories[0].keys())
        writer.writeheader()
        writer.writerows(repositories)

def main():
    print("Fetching users...")
    users = fetch_users()
    save_users_to_csv(users)
    print(f"Saved {len(users)} users to users0.csv")

    print("Fetching repositories...")
    all_repositories = []
    for user in users:
        user_repos = fetch_repositories(user["login"])
        all_repositories.extend(user_repos)
        print(f"Fetched {len(user_repos)} repositories for user {user['login']}")

    save_repositories_to_csv(all_repositories)
    print(f"Saved {len(all_repositories)} repositories to repositories0.csv")

if __name__ == "__main__":
    main()
# Out:
# Fetching users...
# Saved 604 users to users0.csv
# Fetching repositories...
# Fetched 73 repositories for user tiangolo
# Fetched 215 repositories for user schacon
# Fetched 151 repositories for user rwieruch
# Fetched 149 repositories for user shuding
# Fetched 79 repositories for user android10
# Fetched 54 repositories for user marijnh
# Fetched 7 repositories for user mxmnk
# Fetched 110 repositories for user nikic
# Fetched 22 repositories for user greenrobot
# Fetched 32 repositories for user sebastianruder
# Fetched 48 repositories for user vakila
# Fetched 115 repositories for user tonsky
# Fetched 285 repositories for user felixge
# Fetched 129 repositories for user alexeygrigorev
# Fetched 106 repositories for user hanxiao
# Fetched 19 repositories for user ines
# Fetched 73 repositories for user apaszke
# Fetched 175 repositories for user lewagon
# Fetched 105 repositories for user codebytere
# Fetched 152 repositories for user prisma
# Fetched 51 repositories for user armancodv
# Fetched 56 repositories for user peterbourgon
# Fetched 44 repositories for user vanhauser-thc
# Fetched 51 repositories for user KittyGiraudel
# Fetched 200 repositories for user dashersw
# Fetched 319 repositories for user codepo8
# Fetched 42 repositories for user nlohmann
# Fetched 148 repositories for user floooh
# Fetched 20 repositories for user cure53
# Fetched 72 repositories for user nisrulz
# Fetched 39 repositories for user vietnh1009
# Fetched 46 repositories for user pepelsbey
# Fetched 94 repositories for user nschloe
# Fetched 190 repositories for user spacejam
# Fetched 363 repositories for user ligi
# Fetched 41 repositories for user justadudewhohacks
# Fetched 326 repositories for user anaisbetts
# Fetched 25 repositories for user typst
# Fetched 55 repositories for user robb
# Fetched 71 repositories for user schickling
# Fetched 201 repositories for user rkh
# Fetched 71 repositories for user withoutboats
# Fetched 58 repositories for user honnibal
# Fetched 30 repositories for user Roaa94
# Fetched 203 repositories for user janl
# Fetched 117 repositories for user frozeman
# Fetched 48 repositories for user z3tt
# Fetched 28 repositories for user vas3k
# Fetched 50 repositories for user mttkay
# Fetched 57 repositories for user leo
# Fetched 245 repositories for user tomaka
# Fetched 40 repositories for user johnkil
# Fetched 207 repositories for user mxschmitt
# Fetched 132 repositories for user smakosh
# Fetched 32 repositories for user hynek
# Fetched 17 repositories for user poettering
# Fetched 136 repositories for user TejasQ
# Fetched 179 repositories for user AmruthPillai
# Fetched 87 repositories for user chriseth
# Fetched 81 repositories for user roji
# Fetched 34 repositories for user justinmk
# Fetched 139 repositories for user brianamarie
# Fetched 11 repositories for user alireza0
# Fetched 61 repositories for user datitran
# Fetched 76 repositories for user arash-hacker
# Fetched 146 repositories for user maciejwalkowiak
# Fetched 337 repositories for user eps1lon
# Fetched 103 repositories for user MohamedMesto
# Fetched 21 repositories for user solegalli
# Fetched 37 repositories for user mugli
# Fetched 198 repositories for user Byron
# Fetched 207 repositories for user pedromassango
# Fetched 65 repositories for user aFarkas
# Fetched 47 repositories for user mr-mig
# Fetched 38 repositories for user gka
# Fetched 114 repositories for user cytopia
# Fetched 76 repositories for user explosion
# Fetched 13 repositories for user omz
# Fetched 54 repositories for user sujinleeme
# Fetched 40 repositories for user tgalal
# Fetched 200 repositories for user stefanjudis
# Fetched 13 repositories for user cs-MohamedAyman
# Fetched 42 repositories for user dmonad
# Fetched 113 repositories for user ojack
# Fetched 33 repositories for user beorn7
# Fetched 153 repositories for user camunda
# Fetched 110 repositories for user olilarkin
# Fetched 86 repositories for user deliveryhero
# Fetched 81 repositories for user berndruecker
# Fetched 37 repositories for user xct
# Fetched 19 repositories for user rxrbln
# Fetched 106 repositories for user davidchambers
# Fetched 99 repositories for user adamwiggins
# Fetched 91 repositories for user naderman
# Fetched 112 repositories for user fjl
# Fetched 47 repositories for user vitormalencar
# Fetched 139 repositories for user moklick
# Fetched 5 repositories for user rpolonsky
# Fetched 220 repositories for user kashif
# Fetched 46 repositories for user LilithWittmann
# Fetched 314 repositories for user jamesmunns
# Fetched 49 repositories for user pudo
# Fetched 53 repositories for user javierbyte
# Fetched 370 repositories for user meh
# Fetched 69 repositories for user rednafi
# Fetched 79 repositories for user visenger
# Fetched 163 repositories for user brancz
# Fetched 30 repositories for user zaraco
# Fetched 163 repositories for user spacekookie
# Fetched 52 repositories for user ptaoussanis
# Fetched 0 repositories for user traviscibot
# Fetched 61 repositories for user deepset-ai
# Fetched 90 repositories for user emad-elsaid
# Fetched 42 repositories for user mlent
# Fetched 91 repositories for user paolorotolo
# Fetched 26 repositories for user panique
# Fetched 119 repositories for user falkTX
# Fetched 113 repositories for user kof
# Fetched 37 repositories for user pepicrft
# Fetched 92 repositories for user hramezani
# Fetched 258 repositories for user cebe
# Fetched 186 repositories for user PurpleBooth
# Fetched 129 repositories for user bergie
# Fetched 132 repositories for user bkchr
# Fetched 40 repositories for user rahmonov
# Fetched 582 repositories for user derhuerst
# Fetched 145 repositories for user svenfuchs
# Fetched 202 repositories for user nikolasburk
# Fetched 6 repositories for user areyou1or0
# Fetched 97 repositories for user Phantas0s
# Fetched 112 repositories for user tasomaniac
# Fetched 49 repositories for user zalando
# Fetched 23 repositories for user ndrplz
# Fetched 189 repositories for user voronianski
# Fetched 57 repositories for user Expensify
# Fetched 38 repositories for user maateen
# Fetched 92 repositories for user lilic
# Fetched 153 repositories for user fzerorubigd
# Fetched 289 repositories for user endocrimes
# Fetched 70 repositories for user plutov
# Fetched 41 repositories for user kjam
# Fetched 61 repositories for user neelance
# Fetched 63 repositories for user codergogoi
# Fetched 420 repositories for user skade
# Fetched 211 repositories for user msaaddev
# Fetched 36 repositories for user RobertTLange
# Fetched 63 repositories for user anapaulagomes
# Fetched 35 repositories for user infusion
# Fetched 62 repositories for user burakcan
# Fetched 61 repositories for user sschmid
# Fetched 100 repositories for user generall
# Fetched 87 repositories for user SpaceK33z
# Fetched 41 repositories for user rootzoll
# Fetched 99 repositories for user debris
# Fetched 23 repositories for user m0nad
# Fetched 32 repositories for user ozgurozturknet
# Fetched 37 repositories for user cjwirth
# Fetched 471 repositories for user janpio
# Fetched 96 repositories for user philippjfr
# Fetched 137 repositories for user XAMPPRocky
# Fetched 151 repositories for user increpare
# Fetched 92 repositories for user dereuromark
# Fetched 45 repositories for user Tienisto
# Fetched 2 repositories for user iuridepaula
# Fetched 152 repositories for user LefterisJP
# Fetched 43 repositories for user Conchylicultor
# Fetched 452 repositories for user localheinz
# Fetched 122 repositories for user matthiasn
# Fetched 74 repositories for user q9f
# Fetched 38 repositories for user chrieke
# Fetched 51 repositories for user NikolaiT
# Fetched 60 repositories for user thatisuday
# Fetched 60 repositories for user tcurdt
# Fetched 78 repositories for user rumyantseva
# Fetched 245 repositories for user iotaledger
# Fetched 62 repositories for user salihgueler
# Fetched 5 repositories for user mtdvio
# Fetched 166 repositories for user splitbrain
# Fetched 94 repositories for user hukl
# Fetched 81 repositories for user juliusv
# Fetched 495 repositories for user wolfv
# Fetched 169 repositories for user kakkoyun
# Fetched 207 repositories for user manashmandal
# Fetched 157 repositories for user Jolg42
# Fetched 33 repositories for user domschiener
# Fetched 32 repositories for user ebrugulec
# Fetched 109 repositories for user seyfer
# Fetched 84 repositories for user kaisermann
# Fetched 124 repositories for user rohan20
# Fetched 19 repositories for user wix
# Fetched 105 repositories for user cketti
# Fetched 130 repositories for user tasdikrahman
# Fetched 84 repositories for user berstend
# Fetched 179 repositories for user ThisIsMissEm
# Fetched 116 repositories for user greyblake
# Fetched 121 repositories for user christianparpart
# Fetched 56 repositories for user johannesjo
# Fetched 48 repositories for user sheremet-va
# Fetched 39 repositories for user davidsbatista
# Fetched 293 repositories for user ahmedash95
# Fetched 194 repositories for user lislis
# Fetched 348 repositories for user kostasx
# Fetched 69 repositories for user AnirudhDagar
# Fetched 73 repositories for user arximboldi
# Fetched 16 repositories for user mhagger
# Fetched 174 repositories for user boopathi
# Fetched 77 repositories for user DonnchaC
# Fetched 181 repositories for user gouthamve
# Fetched 21 repositories for user jackrusher
# Fetched 51 repositories for user matthiasplappert
# Fetched 20 repositories for user xyflow
# Fetched 131 repositories for user nuhkoca
# Fetched 172 repositories for user xeolabs
# Fetched 78 repositories for user faressoft
# Fetched 79 repositories for user AriaMinaei
# Fetched 132 repositories for user hellofresh
# Fetched 62 repositories for user lukasmasuch
# Fetched 32 repositories for user ikrum
# Fetched 51 repositories for user simoneas02
# Fetched 151 repositories for user asus4
# Fetched 125 repositories for user x42
# Fetched 595 repositories for user blueyed
# Fetched 30 repositories for user peterp
# Fetched 84 repositories for user marinalimeira
# Fetched 103 repositories for user metalmatze
# Fetched 161 repositories for user stefanw
# Fetched 65 repositories for user segunfamisa
# Fetched 62 repositories for user ethanfrey
# Fetched 216 repositories for user PragTob
# Fetched 135 repositories for user roidrage
# Fetched 167 repositories for user hwclass
# Fetched 33 repositories for user juanitorduz
# Fetched 32 repositories for user rdilruba
# Fetched 148 repositories for user okwme
# Fetched 61 repositories for user ivangfr
# Fetched 66 repositories for user abhishek-ch
# Fetched 97 repositories for user aabouzaid
# Fetched 80 repositories for user chrisgrieser
# Fetched 54 repositories for user durran
# Fetched 75 repositories for user sagar-viradiya
# Fetched 84 repositories for user DominicBreuker
# Fetched 51 repositories for user ahmedeltaher
# Fetched 135 repositories for user vertexclique
# Fetched 16 repositories for user photoprism
# Fetched 16 repositories for user mxmxmx
# Fetched 43 repositories for user diessica
# Fetched 147 repositories for user christophergandrud
# Fetched 176 repositories for user drogus
# Fetched 25 repositories for user tessr
# Fetched 229 repositories for user SimonDanisch
# Fetched 28 repositories for user KutayAkalin
# Fetched 142 repositories for user Ohara124c41
# Fetched 31 repositories for user IRCSS
# Fetched 61 repositories for user mntmn
# Fetched 518 repositories for user ff6347
# Fetched 70 repositories for user berinhard
# Fetched 81 repositories for user kianenigma
# Fetched 170 repositories for user SuperQ
# Fetched 0 repositories for user gwens
# Fetched 96 repositories for user hellosagar
# Fetched 100 repositories for user delucis
# Fetched 203 repositories for user hanshuebner
# Fetched 62 repositories for user tmbo
# Fetched 34 repositories for user ueberdosis
# Fetched 123 repositories for user hackebrot
# Fetched 14 repositories for user almaleksia
# Fetched 81 repositories for user AlexDenisov
# Fetched 44 repositories for user danascript
# Fetched 87 repositories for user tarek360
# Fetched 29 repositories for user gusgad
# Fetched 46 repositories for user esc
# Fetched 102 repositories for user mrackwitz
# Fetched 105 repositories for user tillrohrmann
# Fetched 119 repositories for user sschuberth
# Fetched 64 repositories for user hagenburger
# Fetched 48 repositories for user w0rm
# Fetched 355 repositories for user cpanato
# Fetched 139 repositories for user ForsakenHarmony
# Fetched 96 repositories for user azproduction
# Fetched 20 repositories for user lucasmichot
# Fetched 36 repositories for user slint-ui
# Fetched 101 repositories for user jrieke
# Fetched 131 repositories for user ndom91
# Fetched 48 repositories for user lastzero
# Fetched 28 repositories for user adbar
# Fetched 88 repositories for user opf
# Fetched 17 repositories for user fritzing
# Fetched 154 repositories for user turian
# Fetched 81 repositories for user krother
# Fetched 393 repositories for user jpkrohling
# Fetched 52 repositories for user afuh
# Fetched 71 repositories for user prof18
# Fetched 57 repositories for user ManiMozaffar
# Fetched 14 repositories for user timpritlove
# Fetched 102 repositories for user andywer
# Fetched 196 repositories for user schriftgestalt
# Fetched 74 repositories for user MoeinDeveloper92
# Fetched 49 repositories for user aksakalli
# Fetched 204 repositories for user cjolowicz
# Fetched 83 repositories for user lgrammel
# Fetched 12 repositories for user StephanEwen
# Fetched 62 repositories for user boennemann
# Fetched 55 repositories for user TheLartians
# Fetched 16 repositories for user ravanscafi
# Fetched 212 repositories for user turbo
# Fetched 133 repositories for user guitmz
# Fetched 46 repositories for user gumb0
# Fetched 121 repositories for user zubairehman
# Fetched 141 repositories for user squat
# Fetched 11 repositories for user lisacharlotterost
# Fetched 190 repositories for user TimDaub
# Fetched 40 repositories for user burnash
# Fetched 94 repositories for user kkaefer
# Fetched 190 repositories for user axsaucedo
# Fetched 80 repositories for user brauner
# Fetched 193 repositories for user Skn0tt
# Fetched 54 repositories for user aap
# Fetched 14 repositories for user cloudpanel-io
# Fetched 147 repositories for user Fcmam5
# Fetched 146 repositories for user weaveworks
# Fetched 141 repositories for user juliuste
# Fetched 105 repositories for user mrtazz
# Fetched 157 repositories for user acao
# Fetched 64 repositories for user fehmicansaglam
# Fetched 166 repositories for user runningcode
# Fetched 42 repositories for user whoenig
# Fetched 90 repositories for user fortmarek
# Fetched 13 repositories for user baptistebriel
# Fetched 57 repositories for user soundcloud
# Fetched 78 repositories for user laramartin
# Fetched 96 repositories for user ashiishme
# Fetched 117 repositories for user MarkusH
# Fetched 79 repositories for user jhass
# Fetched 108 repositories for user imskr
# Fetched 29 repositories for user RomelTorres
# Fetched 132 repositories for user chrisguttandin
# Fetched 76 repositories for user andela-sjames
# Fetched 36 repositories for user laf0rge
# Fetched 99 repositories for user jamiehannaford
# Fetched 41 repositories for user Pisush
# Fetched 161 repositories for user ym
# Fetched 121 repositories for user MichaelKreil
# Fetched 135 repositories for user perusio
# Fetched 19 repositories for user marcinguy
# Fetched 105 repositories for user fractaledmind
# Fetched 133 repositories for user alexbeletsky
# Fetched 251 repositories for user martinklepsch
# Fetched 122 repositories for user fineanmol
# Fetched 55 repositories for user doctolib
# Fetched 185 repositories for user janeczku
# Fetched 134 repositories for user manojpandey
# Fetched 42 repositories for user gorgos
# Fetched 149 repositories for user traumverloren
# Fetched 19 repositories for user syllog1sm
# Fetched 12 repositories for user jackschaedler
# Fetched 157 repositories for user dirkschumacher
# Fetched 33 repositories for user ngoduykhanh
# Fetched 52 repositories for user woachk
# Fetched 204 repositories for user sdepold
# Fetched 83 repositories for user smurawski
# Fetched 84 repositories for user Kardelio
# Fetched 186 repositories for user marimeireles
# Fetched 61 repositories for user pauladiniz
# Fetched 146 repositories for user coderobe
# Fetched 59 repositories for user abdulfatir
# Fetched 62 repositories for user CesarValiente
# Fetched 57 repositories for user jdennes
# Fetched 26 repositories for user carolstran
# Fetched 7 repositories for user spicedacademy
# Fetched 282 repositories for user htbkoo
# Fetched 105 repositories for user bluemix
# Fetched 127 repositories for user janlelis
# Fetched 6 repositories for user andydandy74
# Fetched 33 repositories for user zoepage
# Fetched 75 repositories for user aqrln
# Fetched 82 repositories for user JustinShenk
# Fetched 14 repositories for user gkmngrgn
# Fetched 46 repositories for user tssovi
# Fetched 58 repositories for user mwarning
# Fetched 60 repositories for user brunagil
# Fetched 95 repositories for user mmourafiq
# Fetched 138 repositories for user nikku
# Fetched 16 repositories for user IliaKani
# Fetched 42 repositories for user deanm
# Fetched 197 repositories for user thejonanshow
# Fetched 141 repositories for user cmaureir
# Fetched 268 repositories for user discordianfish
# Fetched 68 repositories for user seiflotfy
# Fetched 28 repositories for user yjs
# Fetched 26 repositories for user zalandoresearch
# Fetched 87 repositories for user larsxschneider
# Fetched 303 repositories for user mindreframer
# Fetched 34 repositories for user felipecruz
# Fetched 382 repositories for user johnjohndoe
# Fetched 90 repositories for user yomete
# Fetched 56 repositories for user lourot
# Fetched 43 repositories for user Victoriapm
# Fetched 253 repositories for user missinglink
# Fetched 26 repositories for user janober
# Fetched 95 repositories for user yogiben
# Fetched 50 repositories for user anna-geller
# Fetched 23 repositories for user fhueske
# Fetched 179 repositories for user nickstenning
# Fetched 53 repositories for user adriankumpf
# Fetched 30 repositories for user laurmaedje
# Fetched 90 repositories for user vasco-santos
# Fetched 32 repositories for user kshitij10496
# Fetched 40 repositories for user neobrain
# Fetched 97 repositories for user jfahrenkrug
# Fetched 90 repositories for user atilafassina
# Fetched 4 repositories for user d3vilbug
# Fetched 65 repositories for user grobie
# Fetched 113 repositories for user AlaaAttya
# Fetched 39 repositories for user streadway
# Fetched 477 repositories for user objcio
# Fetched 61 repositories for user Drakulix
# Fetched 44 repositories for user DenisovAV
# Fetched 172 repositories for user davidfurlong
# Fetched 35 repositories for user objectbox
# Fetched 93 repositories for user goetas
# Fetched 212 repositories for user rafaeljesus
# Fetched 21 repositories for user vitling
# Fetched 21 repositories for user sejalv
# Fetched 35 repositories for user hamoid
# Fetched 42 repositories for user anaschwendler
# Fetched 140 repositories for user daniel-j-h
# Fetched 199 repositories for user Nitrokey
# Fetched 7 repositories for user chrxh
# Fetched 291 repositories for user arianvp
# Fetched 73 repositories for user al2na
# Fetched 44 repositories for user mishushakov
# Fetched 477 repositories for user mr-c
# Fetched 52 repositories for user yogmel
# Fetched 81 repositories for user thyrlian
# Fetched 86 repositories for user adrianheine
# Fetched 149 repositories for user unnamedd
# Fetched 41 repositories for user septag
# Fetched 9 repositories for user alanakbik
# Fetched 34 repositories for user lorey
# Fetched 93 repositories for user talitaoliveira
# Fetched 1 repositories for user Fouloscopie
# Fetched 107 repositories for user marktani
# Fetched 53 repositories for user sacridini
# Fetched 146 repositories for user asaaki
# Fetched 30 repositories for user nomicode
# Fetched 63 repositories for user angelikatyborska
# Fetched 18 repositories for user s1monw
# Fetched 224 repositories for user Licenser
# Fetched 196 repositories for user Khaledgarbaya
# Fetched 297 repositories for user bennycode
# Fetched 43 repositories for user Kovah
# Fetched 48 repositories for user mrflix
# Fetched 48 repositories for user tsterbak
# Fetched 41 repositories for user sorenbs
# Fetched 128 repositories for user reuben
# Fetched 2 repositories for user RosaWagner
# Fetched 169 repositories for user rixx
# Fetched 41 repositories for user dpreussler
# Fetched 13 repositories for user rivo
# Fetched 105 repositories for user sotte
# Fetched 64 repositories for user lucaong
# Fetched 96 repositories for user spacecowb0y
# Fetched 100 repositories for user janmonschke
# Fetched 21 repositories for user fabsx00
# Fetched 28 repositories for user candostdagdeviren
# Fetched 127 repositories for user denisdefreyne
# Fetched 15 repositories for user MKRLancer
# Fetched 141 repositories for user kenshinji
# Fetched 56 repositories for user cmichi
# Fetched 21 repositories for user jmattheis
# Fetched 229 repositories for user lstoll
# Fetched 77 repositories for user Sly777
# Fetched 303 repositories for user OskarStark
# Fetched 25 repositories for user esoxjem
# Fetched 392 repositories for user saschanaz
# Fetched 157 repositories for user clovisdasilvaneto
# Fetched 274 repositories for user montogeek
# Fetched 20 repositories for user Letty
# Fetched 72 repositories for user autophagy
# Fetched 58 repositories for user marcobiedermann
# Fetched 23 repositories for user efemoney
# Fetched 24 repositories for user niderhoff
# Fetched 46 repositories for user progapandist
# Fetched 129 repositories for user marinho
# Fetched 97 repositories for user omergulen
# Fetched 153 repositories for user kimar
# Fetched 74 repositories for user devonestes
# Fetched 191 repositories for user hartwork
# Fetched 43 repositories for user aarlt
# Fetched 83 repositories for user manuelbieh
# Fetched 46 repositories for user irh
# Fetched 123 repositories for user s-soroosh
# Fetched 78 repositories for user lukasoppermann
# Fetched 70 repositories for user joseliacosta
# Fetched 13 repositories for user szaimen
# Fetched 49 repositories for user polarity
# Fetched 177 repositories for user Rebaiahmed
# Fetched 79 repositories for user geekdada
# Fetched 56 repositories for user hanakamer
# Fetched 45 repositories for user Kriesse
# Fetched 69 repositories for user fmeyer
# Fetched 55 repositories for user mlegy
# Fetched 94 repositories for user mirshko
# Fetched 179 repositories for user Dylan-DPC-zz
# Fetched 120 repositories for user linki
# Fetched 38 repositories for user danielpaulus
# Fetched 58 repositories for user AbdullahBakir97
# Fetched 82 repositories for user keremciu
# Fetched 219 repositories for user aep
# Fetched 71 repositories for user msoos
# Fetched 70 repositories for user stanislaw
# Fetched 22 repositories for user BenchR267
# Fetched 26 repositories for user chrippa
# Fetched 21 repositories for user Goldziher
# Fetched 34 repositories for user moiseshorta
# Fetched 166 repositories for user bashofmann
# Fetched 52 repositories for user Mark2Mark
# Fetched 74 repositories for user LukasReschke
# Fetched 74 repositories for user phazonoverload
# Fetched 68 repositories for user jenskutilek
# Fetched 60 repositories for user v-thakkar
# Fetched 172 repositories for user 343max
# Fetched 43 repositories for user joaomilho
# Fetched 80 repositories for user akrennmair
# Fetched 84 repositories for user PavelLaptev
# Fetched 63 repositories for user kirel
# Fetched 169 repositories for user robinpokorny
# Fetched 99 repositories for user mschneider
# Fetched 77 repositories for user oleiade
# Fetched 11 repositories for user philippkuehn
# Fetched 169 repositories for user froschi
# Fetched 43 repositories for user tmylk
# Fetched 155 repositories for user EmaSuriano
# Fetched 53 repositories for user LeonardoCardoso
# Fetched 294 repositories for user JeroenDeDauw
# Fetched 22 repositories for user Musti4096
# Fetched 353 repositories for user finnp
# Fetched 49 repositories for user vecna
# Fetched 94 repositories for user zeenix
# Fetched 91 repositories for user alfredfrancis
# Fetched 38 repositories for user polykit
# Fetched 253 repositories for user MichaelKohler
# Fetched 29 repositories for user helmuthdu
# Fetched 174 repositories for user harshil1712
# Fetched 80 repositories for user illume
# Fetched 308 repositories for user 0mp
# Fetched 239 repositories for user mrchrisadams
# Fetched 169 repositories for user robinboehm
# Fetched 55 repositories for user katiayn
# Fetched 5 repositories for user kurasu
# Fetched 27 repositories for user tunavargi
# Fetched 43 repositories for user miconda
# Fetched 105 repositories for user mohsenoid
# Fetched 55 repositories for user tmspzz
# Fetched 53 repositories for user tanvir002700
# Fetched 94 repositories for user cristianoliveira
# Fetched 66 repositories for user HeyPouya
# Fetched 12 repositories for user rockstaedt
# Fetched 35 repositories for user rishimohan
# Fetched 179 repositories for user chris-rock
# Fetched 21 repositories for user khanzadimahdi
# Fetched 73 repositories for user codeliner
# Fetched 353 repositories for user sunsided
# Fetched 168 repositories for user myobie
# Fetched 20 repositories for user mymindishazel
# Fetched 28 repositories for user divyenduz
# Fetched 37 repositories for user fabianfett
# Fetched 306 repositories for user MedRedha
# Fetched 42 repositories for user durannumit
# Fetched 106 repositories for user cornelius
# Fetched 47 repositories for user BenjaminBossan
# Fetched 51 repositories for user adewes
# Fetched 11 repositories for user anna-carroll
# Fetched 20 repositories for user pierluigiferrari
# Fetched 55 repositories for user Fluepke
# Fetched 53 repositories for user Schaeff
# Fetched 120 repositories for user luqmanoop
# Fetched 30 repositories for user amn41
# Fetched 64 repositories for user adzialocha
# Fetched 97 repositories for user FACorreiaa
# Fetched 30 repositories for user mikiobraun
# Fetched 77 repositories for user natalyapeixoto
# Fetched 48 repositories for user znarf
# Fetched 15 repositories for user ogoffart
# Fetched 311 repositories for user vadorovsky
# Fetched 48 repositories for user chootka
# Fetched 63 repositories for user mzaks
# Fetched 74 repositories for user knutin
# Fetched 44 repositories for user batin
# Fetched 73 repositories for user nulltea
# Fetched 234 repositories for user reactormonk
# Fetched 34 repositories for user Shpota
# Fetched 62 repositories for user holgerd77
# Fetched 42 repositories for user Dineshkarthik
# Fetched 135 repositories for user Robbepop
# Fetched 30 repositories for user mustafaozhan
# Fetched 100 repositories for user nmicht
# Fetched 92 repositories for user carlosmn
# Fetched 26 repositories for user roquebuarquejr
# Fetched 1 repositories for user hendrikhofstadt
# Fetched 13 repositories for user zutrinken
# Fetched 90 repositories for user cristim
# Fetched 42 repositories for user mehd-io
# Fetched 187 repositories for user soulshake
# Saved 60847 repositories to repositories0.csv

# %% [markdown]
# #Cleaning up the scraped csv files

# %% [markdown]
# After scraping the raw/uncleaned users0.csv and repositories0.csv files, I loaded them into Pandas dataframe and cleaned them up to create users.csv and repositories.csv files

# %% [markdown]
# ###users.csv

# %% [markdown]
# Loading the raw/uncleaned users0.csv file for cleaning.

# %%
import pandas as pd
import numpy as np

# Load the data the uncleaned csv files
users0_df = pd.read_csv('users0.csv')
repos0_df = pd.read_csv('repositories0.csv')

# %%
users0_df.head()
# Out:
#        login               name       company         location  \
# 0   tiangolo  Sebastián Ramírez           NaN  Berlin, Germany
# 1    schacon       Scott Chacon  GITBUTLERAPP  Berlin, Germany
# 2   rwieruch      Robin Wieruch           NaN    Berlin/Remote
# 3    shuding           Shu Ding        VERCEL           Berlin
# 4  android10     Fernando Cejas      PEPPR-IO  Berlin, Germany
#
#                          email hireable  \
# 0           tiangolo@gmail.com     True
# 1            schacon@gmail.com      NaN
# 2                          NaN     True
# 3                    g@shud.in      NaN
# 4  android10@fernandocejas.com     True
#
#                                                  bio  public_repos  followers  \
# 0  Creator of FastAPI, Typer, SQLModel, Asyncer, ...            73      26442
# 1                                                NaN           215      13756
# 2  React & Next.js • JavaScript & TypeScript • Fr...           151       8617
# 3  Be curious. Read widely. Try new things. — aar...           149       6756
# 4  Quantum Engineering at @Qruise-ai. Former Dire...            79       6716
#
#    following            created_at
# 0          3  2012-01-12T22:37:04Z
# 1         26  2008-01-27T17:19:28Z
# 2         30  2012-10-03T15:11:48Z
# 3        345  2013-02-23T07:46:30Z
# 4         85  2012-01-20T21:35:31Z

# %% [markdown]
# Replacing all NaN values with empty string (except for the 'hireable' column)

# %%
users0_df.loc[:, users0_df.columns != 'hireable'] = users0_df.loc[:, users0_df.columns != 'hireable'].fillna('')

# %% [markdown]
# Replacing the True and NaN values in hireable column with 'true' and 'false'

# %%
users0_df['hireable'] = users0_df['hireable'].replace(True,'true')

# %%
users0_df['hireable'] = users0_df['hireable'].fillna('false')

# %% [markdown]
# Checking the dataframe after cleaning operations

# %%
users0_df.head()
# Out:
#        login               name       company         location  \
# 0   tiangolo  Sebastián Ramírez                Berlin, Germany
# 1    schacon       Scott Chacon  GITBUTLERAPP  Berlin, Germany
# 2   rwieruch      Robin Wieruch                  Berlin/Remote
# 3    shuding           Shu Ding        VERCEL           Berlin
# 4  android10     Fernando Cejas      PEPPR-IO  Berlin, Germany
#
#                          email hireable  \
# 0           tiangolo@gmail.com     true
# 1            schacon@gmail.com    false
# 2                                  true
# 3                    g@shud.in    false
# 4  android10@fernandocejas.com     true
#
#                                                  bio  public_repos  followers  \
# 0  Creator of FastAPI, Typer, SQLModel, Asyncer, ...            73      26442
# 1                                                              215      13756
# 2  React & Next.js • JavaScript & TypeScript • Fr...           151       8617
# 3  Be curious. Read widely. Try new things. — aar...           149       6756
# 4  Quantum Engineering at @Qruise-ai. Former Dire...            79       6716
#
#    following            created_at
# 0          3  2012-01-12T22:37:04Z
# 1         26  2008-01-27T17:19:28Z
# 2         30  2012-10-03T15:11:48Z
# 3        345  2013-02-23T07:46:30Z
# 4         85  2012-01-20T21:35:31Z

# %% [markdown]
# We can see above we have obtained clean dataframe now.

# %% [markdown]
# Saving the cleaned dataframe as users.csv file

# %%
users0_df.to_csv('users.csv',index = False)

# %% [markdown]
# ###repositories.csv

# %% [markdown]
# Loading the raw/uncleaned repositories0.csv file for cleaning.

# %%
repos0_df = pd.read_csv('repositories0.csv')

# %%
repos0_df.head()
# Out:
#       login                                    full_name  \
# 0  tiangolo                              tiangolo/a2wsgi
# 1  tiangolo                             tiangolo/alembic
# 2  tiangolo            tiangolo/anaconda_cluster_install
# 3  tiangolo  tiangolo/angular-docker-multi-stage-example
# 4  tiangolo                     tiangolo/annotated-types
#
#              created_at  stargazers_count  watchers_count language  \
# 0  2024-01-07T20:24:07Z                10              10      NaN
# 1  2020-05-22T09:50:31Z                 5               5      NaN
# 2  2015-03-11T14:58:44Z                 5               5    Shell
# 3  2017-10-02T18:43:28Z                15              15      NaN
# 4  2023-08-27T14:32:00Z                 8               8      NaN
#
#    has_projects  has_wiki license_name
# 0          True      True   apache-2.0
# 1          True      True          mit
# 2          True      True          NaN
# 3          True      True          NaN
# 4          True     False          mit

# %% [markdown]
# Replacing all NaN values with empty string (except for the 'has_projects' & 'has_wiki' columns)

# %%
repos0_df.loc[:, repos0_df.columns.difference(['has_projects','has_wiki'])] = repos0_df.loc[
    :, repos0_df.columns.difference(['has_projects','has_wiki'])
].fillna('')

# %% [markdown]
# Checking the datatype of 'has_projects' and 'has_wiki' columns

# %%
data_type = repos0_df['has_projects'].dtype
print(f"Data type of 'has_projects': {data_type}")
# Out:
# Data type of 'has_projects': bool

# %%
data_type = repos0_df['has_wiki'].dtype
print(f"Data type of 'has_wiki': {data_type}")
# Out:
# Data type of 'has_wiki': bool

# %% [markdown]
# The datatype seems to be bool. Changing them to string type

# %%
# Change the dtype of 'has_projects' and 'has_wiki' columns to str
repos0_df['has_projects'] = repos0_df['has_projects'].astype(str)
repos0_df['has_wiki'] = repos0_df['has_wiki'].astype(str)

# Check the updated data types
print(repos0_df[['has_projects', 'has_wiki']].dtypes)
# Out:
# has_projects    object
# has_wiki        object
# dtype: object

# %% [markdown]
# Replacing the 'True' and 'False' values in hireable column with 'true' and 'false'

# %%
repos0_df['has_projects'] = repos0_df['has_projects'].replace('True','true')
repos0_df['has_projects'] = repos0_df['has_projects'].replace('False','false')

repos0_df['has_wiki'] = repos0_df['has_wiki'].replace('True','true')
repos0_df['has_wiki'] = repos0_df['has_wiki'].replace('False','false')

# %%
repos0_df.head()
# Out:
#       login                                    full_name  \
# 0  tiangolo                              tiangolo/a2wsgi
# 1  tiangolo                             tiangolo/alembic
# 2  tiangolo            tiangolo/anaconda_cluster_install
# 3  tiangolo  tiangolo/angular-docker-multi-stage-example
# 4  tiangolo                     tiangolo/annotated-types
#
#              created_at  stargazers_count  watchers_count language  \
# 0  2024-01-07T20:24:07Z                10              10
# 1  2020-05-22T09:50:31Z                 5               5
# 2  2015-03-11T14:58:44Z                 5               5    Shell
# 3  2017-10-02T18:43:28Z                15              15
# 4  2023-08-27T14:32:00Z                 8               8
#
#   has_projects has_wiki license_name
# 0         true     true   apache-2.0
# 1         true     true          mit
# 2         true     true
# 3         true     true
# 4         true    false          mit

# %% [markdown]
# Now the file seems to be cleaned. Let's store it as repositories.csv

# %%
repos0_df.to_csv('repositories.csv', index = False)

# %% [markdown]
# #Questions & Solutions

# %% [markdown]
# Loading the cleaned users.csv and repositories.csv files into Pandas dataframe to solve the questions

# %%
users_df = pd.read_csv('users.csv', na_filter=False, dtype={'hireable': str})

# %%
users_df.head()
# Out:
#        login               name       company         location  \
# 0   tiangolo  Sebastián Ramírez                Berlin, Germany
# 1    schacon       Scott Chacon  GITBUTLERAPP  Berlin, Germany
# 2   rwieruch      Robin Wieruch                  Berlin/Remote
# 3    shuding           Shu Ding        VERCEL           Berlin
# 4  android10     Fernando Cejas      PEPPR-IO  Berlin, Germany
#
#                          email hireable  \
# 0           tiangolo@gmail.com     true
# 1            schacon@gmail.com    false
# 2                                  true
# 3                    g@shud.in    false
# 4  android10@fernandocejas.com     true
#
#                                                  bio  public_repos  followers  \
# 0  Creator of FastAPI, Typer, SQLModel, Asyncer, ...            73      26442
# 1                                                              215      13756
# 2  React & Next.js • JavaScript & TypeScript • Fr...           151       8617
# 3  Be curious. Read widely. Try new things. — aar...           149       6756
# 4  Quantum Engineering at @Qruise-ai. Former Dire...            79       6716
#
#    following            created_at
# 0          3  2012-01-12T22:37:04Z
# 1         26  2008-01-27T17:19:28Z
# 2         30  2012-10-03T15:11:48Z
# 3        345  2013-02-23T07:46:30Z
# 4         85  2012-01-20T21:35:31Z

# %%
repos_df = pd.read_csv('repositories.csv', na_filter = False, dtype={'has_projects':str, 'has_wiki':str})

# %%
repos_df.head()
# Out:
#       login                                    full_name  \
# 0  tiangolo                              tiangolo/a2wsgi
# 1  tiangolo                             tiangolo/alembic
# 2  tiangolo            tiangolo/anaconda_cluster_install
# 3  tiangolo  tiangolo/angular-docker-multi-stage-example
# 4  tiangolo                     tiangolo/annotated-types
#
#              created_at  stargazers_count  watchers_count language  \
# 0  2024-01-07T20:24:07Z                10              10
# 1  2020-05-22T09:50:31Z                 5               5
# 2  2015-03-11T14:58:44Z                 5               5    Shell
# 3  2017-10-02T18:43:28Z                15              15
# 4  2023-08-27T14:32:00Z                 8               8
#
#   has_projects has_wiki license_name
# 0         true     true   apache-2.0
# 1         true     true          mit
# 2         true     true
# 3         true     true
# 4         true    false          mit

# %% [markdown]
# ##Q1

# %%
# Filter for users located in Berlin
berlin_users = users_df[users_df['location'].str.contains('Berlin', case=False)]

# Sort by followers and get the top 5
top_5_users = berlin_users.nlargest(5, 'followers')

# Extract the login names in order, comma-separated
top_5_logins = ','.join(top_5_users['login'])

print(top_5_logins)
# Out:
# tiangolo,schacon,rwieruch,shuding,android10

# %% [markdown]
# ##Q2

# %%
users_df['created_at'] = pd.to_datetime(users_df['created_at'])

# Sort by 'created_at' in ascending order and select the first 5
earliest_users = users_df.nsmallest(5, 'created_at')

# Get the logins as a comma-separated string
logins = ','.join(earliest_users['login'].tolist())

print(logins)
# Out:
# schacon,adamwiggins,myobie,lstoll,znarf

# %% [markdown]
# ##Q3

# %%
# Merge users_df and repo_df on the 'login' column to associate users with their repositories
merged_df = pd.merge(users_df, repos_df, on='login', how='inner')

# Count the occurrences of each license, ignoring missing values
popular_licenses = merged_df['license_name'].dropna().value_counts()

# Get the top 3 most common licenses
top_licenses = popular_licenses.nlargest(3)

# List the license names as a comma-separated string
license_list = ','.join(top_licenses.index)

print(license_list)
# Out:
# mit,apache-2.0,other

# %% [markdown]
# ##Q4

# %%
# Clean the company names
users_df['company'] = users_df['company'].str.strip().str.lstrip('@').str.upper()

# Count the occurrences of each company
company_counts = users_df['company'].value_counts()

# Get the company with the highest count
most_common_company = company_counts.idxmax()

print(most_common_company)
# Out:
# MICROSOFT

# %% [markdown]
# ##Q5

# %%
# Filter out repositories with empty language entries
repos_with_language = repos_df[repos_df['language'] != ""]

# Count each programming language and find the most popular
most_popular_language = repos_with_language['language'].value_counts().idxmax()
most_popular_language
# Out:
# 'JavaScript'

# %% [markdown]
# ##Q6

# %%
# Convert 'created_at' to datetime
users_df['created_at'] = pd.to_datetime(users_df['created_at'])

# Filter users who joined after 2020
recent_users_df = users_df[users_df['created_at'] > '2020-01-01']

# Merge with the repo DataFrame
merged_df = pd.merge(recent_users_df, repo_df, on='login', how='inner')

# Count the occurrences of each programming language, ignoring missing values
language_counts = merged_df['language'].dropna().value_counts()

# Get the second most common programming language
second_most_popular_language = language_counts.nlargest(2).index[1]

print(second_most_popular_language)
# Out:
# JavaScript

# %% [markdown]
# ##Q7

# %%
# Filter out repositories with empty language entries
repos_with_language = repos_df[repos_df['language'] != ""]

# Calculate the average number of stars per language
avg_stars_per_language = repos_with_language.groupby('language')['stargazers_count'].mean()

# Find the language with the highest average number of stars
highest_avg_stars_language = avg_stars_per_language.idxmax()
highest_avg_stars_value = avg_stars_per_language.max()

highest_avg_stars_language, round(highest_avg_stars_value, 3)
# Out:
# ('Fluent', 12939.0)

# %% [markdown]
# ##Q8

# %%
# Calculate leader_strength
users_df['leader_strength'] = users_df['followers'] / (1 + users_df['following'])

# Sort by leader_strength in descending order and select the top 5
top_leaders = users_df.nlargest(5, 'leader_strength')

# Get the logins as a comma-separated string
leader_logins = ','.join(top_leaders['login'].tolist())

print(leader_logins)
# Out:
# tiangolo,marijnh,vakila,alexeygrigorev,lewagon

# %% [markdown]
# ##Q9

# %%
# Calculate the correlation between followers and public_repos
correlation = users_df['followers'].corr(users_df['public_repos'])

print(correlation)
# Out:
# 0.01649558986796753

# %% [markdown]
# ##Q10

# %%
import statsmodels.api as sm

# Define the independent variable (public_repos) and dependent variable (followers)
X = users_df['public_repos']
y = users_df['followers']

# Add a constant to the independent variable for the intercept
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Get the coefficient for public_repos
additional_followers_per_repo = model.params['public_repos']

print(additional_followers_per_repo)
# Out:
# 0.27903835231766005

# %% [markdown]
# ##Q11

# %%
# Convert 'true'/'false' strings to boolean
repos_df['has_projects'] = repos_df['has_projects'].map({'true': True, 'false': False})
repos_df['has_wiki'] = repos_df['has_wiki'].map({'true': True, 'false': False})

# Create binary columns for has_projects and has_wiki
repos_df['projects_enabled'] = repos_df['has_projects'].astype(int)
repos_df['wiki_enabled'] = repos_df['has_wiki'].astype(int)

# Calculate the correlation
correlation = repos_df['projects_enabled'].corr(repos_df['wiki_enabled'])

# Print the correlation rounded to 3 decimal places
print(round(correlation, 3))
# Out:
# 0.404

# %% [markdown]
# ##Q12

# %%
# Calculate the average number of following for hireable users (hireable == 'true')
avg_following_hireable = users_df[users_df['hireable'] == 'true']['following'].mean()

# Calculate the average number of following for non-hireable users (hireable == 'false')
avg_following_non_hireable = users_df[users_df['hireable'] == 'false']['following'].mean()

# Calculate the difference
difference = round(avg_following_hireable - avg_following_non_hireable, 3)

print(difference)
# Out:
# 47.489

# %% [markdown]
# ##Q13

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Filter out rows without a bio
bio_df = users_df[users_df['bio'].notna()]

# Calculate the word count for each bio
bio_df['bio_word_count'] = bio_df['bio'].apply(lambda x: len(x.split()))

# Prepare data for regression: bio word count as predictor (X) and followers as target (y)
X = bio_df[['bio_word_count']].values  # Reshape for sklearn compatibility
y = bio_df['followers'].values

# Perform linear regression
model = LinearRegression()
model.fit(X, y)

# Get the slope (coefficient of bio word count)
slope = round(model.coef_[0], 3)

print(f"Regression slope of followers on bio word count: {slope}")
# Out:
# Regression slope of followers on bio word count: 28.506
# <ipython-input-52-96c76ed03259>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bio_df['bio_word_count'] = bio_df['bio'].apply(lambda x: len(x.split()))

# %% [markdown]
# ##Q14

# %%
# Convert 'created_at' to datetime format
repo_df['created_at'] = pd.to_datetime(repo_df['created_at'], utc=True)

# Filter repositories created on weekends (Saturday = 5, Sunday = 6 in Python datetime)
weekend_repos = repo_df[repo_df['created_at'].dt.weekday >= 5]

# Count the number of weekend repos per user
weekend_repo_counts = weekend_repos['login'].value_counts()

# Get the top 5 users with the most weekend repositories
top_5_weekend_users = weekend_repo_counts.head(5).index.tolist()

# Convert to comma-separated string
top_5_weekend_users_str = ', '.join(top_5_weekend_users)

print(f"Top 5 users with the most repositories created on weekends: {top_5_weekend_users_str}")
# Out:
# Top 5 users with the most repositories created on weekends: derhuerst, janpio, saschanaz, blueyed, jamesmunns
# <ipython-input-53-6c4946b4d237>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   repo_df['created_at'] = pd.to_datetime(repo_df['created_at'], utc=True)

# %% [markdown]
# ##Q15

# %%
# Ensure the 'hireable' column has consistent boolean-like values for comparison
users_df['hireable'] = users_df['hireable'].fillna('false').astype(str).str.lower()

# Filter for users with an email
users_with_email = users_df[users_df['email'] != '']

# Calculate the fractions for hireable and non-hireable users with emails
hireable_true_count = users_df[users_df['hireable'] == 'true'].shape[0]
hireable_false_count = users_df[users_df['hireable'] == 'false'].shape[0]

# Calculate fractions safely, handling cases where counts may be zero
hireable_with_email_fraction = (
    users_with_email[users_with_email['hireable'] == 'true'].shape[0] / hireable_true_count
    if hireable_true_count > 0 else 0
)

non_hireable_with_email_fraction = (
    users_with_email[users_with_email['hireable'] == 'false'].shape[0] / hireable_false_count
    if hireable_false_count > 0 else 0
)

# Calculate the difference and round to 3 decimal places
fraction_difference = round(hireable_with_email_fraction - non_hireable_with_email_fraction, 3)
fraction_difference
# Out:
# -0.012

# %% [markdown]
# ##Q16

# %%
# Filter out missing names and trim whitespace
cleaned_users_df = cleaned_users_df[cleaned_users_df['name'].str.strip() != '']

# Extract the surnames (last word in the name)
cleaned_users_df['surname'] = cleaned_users_df['name'].str.split().str[-1]

# Count the occurrences of each surname
surname_counts = cleaned_users_df['surname'].value_counts()

# Find the maximum count
max_count = surname_counts.max()

# Get the most common surnames
most_common_surnames = surname_counts[surname_counts == max_count].index.tolist()

# Sort the surnames alphabetically
most_common_surnames.sort()

# Join them as a comma-separated string
result = ','.join(most_common_surnames)

print(result)
# Out:
# Schneider
# <ipython-input-33-675efe8364b5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_users_df['surname'] = cleaned_users_df['name'].str.split().str[-1]
